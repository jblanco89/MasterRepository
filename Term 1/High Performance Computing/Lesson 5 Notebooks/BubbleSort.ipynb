# %%
from time import time

def ordenacionBurbuja(lista):
    'Variable global que puede ser usada fuera  de la funciÃ³n'
    global numComparaciones
    n = len(lista)
    for i in range(1, n):
        for j in range(n-i):
            numComparaciones += 1
            if lista[j] > lista[j+1]:
                'intercambio de valores'
                lista[j], lista[j+1] = lista[j+1], lista[j]

lista = [35, 36, 17, 73,8, 0]
numComparaciones = 0
t0 = time()
ordenacionBurbuja(lista)
t1 = time()

print ("Lista ordenada:")
print(lista)
print ("Tiempo: {0:f} segundos".format(t1 - t0))
print ("Comparaciones:", numComparaciones)
# Out:
# Lista ordenada:
# [0, 8, 17, 35, 36, 73]
# Tiempo: 0.000000 segundos
# Comparaciones: 15

# %%
lista = [35, 36, 17, 73,8, 0,27,32,1,89,34,67,2,3,20,5,6,43,99,56,12,44,67,54,33,18,22,66,41,87,71,11,25]


numComparaciones = 0
t0 = time()
ordenacionBurbuja(lista)
t1 = time()

print ("Lista ordenada:")
print(lista)
print ("Tiempo: {0:f} segundos".format(t1 - t0))
print ("Comparaciones:", numComparaciones)
# Out:
# Lista ordenada:
# [0, 1, 2, 3, 5, 6, 8, 11, 12, 17, 18, 20, 22, 25, 27, 32, 33, 34, 35, 36, 41, 43, 44, 54, 56, 66, 67, 67, 71, 73, 87, 89, 99]
# Tiempo: 0.000000 segundos
# Comparaciones: 528
